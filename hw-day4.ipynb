# %%
class GetPython():
    def get_str(self):
        self.user_input = input("Enter YouR CREDIT CARD NUMBER")
    def return_str(self):
        print(self.user_input.upper())
        
test = GetPython()
test.get_str()
test.return_str()
# Out:
# ASJKFDDF

# %%
class ShoppingList():


products = []

   def __init__(self, add, remove, show):
        self.add = add
        self.remove = remove
        self.show = show

    def showShoppingList(self):
        for show in self.show:
            print(products)

    def addShoppingList(self):
        for add in self.add:
        products = input("What would you like to add?")
        self.add.append(products)

    def delShoppingList(self):
        for remove in self.remove:
            del (products)

shoppingCart = ShoppingList()


def run():
    while True:
        response = input("Add / Remove / Show / Quit ")

        if response.lower() == 'quit':
            shoppingCart.showShoppingList()
            print("Thanks for shopping")
            break
        if response.lower() == 'add':
            shoppingCart.ShoppingList()


run()
